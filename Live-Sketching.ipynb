# %%
##Live Sketching
###Author - Hari Vigneshwaran S

# %%
import keras
import cv2
import numpy as np
import matplotlib
print (cv2.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import keras
#       2 import cv2
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'keras'

# %%
import cv2
import numpy as np

# Our sketch generating function
def sketch(image):
    # Convert image to grayscale
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Clean up image using Guassian Blur
    img_gray_blur = cv2.GaussianBlur(img_gray, (5,5), 0)
    
    # Extract edges
    canny_edges = cv2.Canny(img_gray_blur, 20, 50)
    
    # Do an invert binarize the image 
    ret, mask = cv2.threshold(canny_edges, 70, 255, cv2.THRESH_BINARY_INV)
    return mask


# Initialize webcam, cap is the object provided by VideoCapture
# It contains a boolean indicating if it was sucessful (ret)
# It also contains the images collected from the webcam (frame)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow("Hari's Live Sketcher", sketch(frame))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
# Release camera and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 1   HIToolbox                           0x00000001933e45c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001933e4188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x0000000193387310 SetMenuBarObscured + 372
# 4   HIToolbox                           0x0000000193386ee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 5   HIToolbox                           0x0000000193380fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 6   HIToolbox                           0x0000000193347cd0 _NotifyEventLoopObservers + 176
# 7   AppKit                              0x000000018d0bf5b0 -[NSWindow(NSEventRouting) _handleMouseDownEvent:isDelayedEvent:] + 2428
# 8   AppKit                              0x000000018d049ab8 -[NSWindow(NSEventRouting) _reallySendEvent:isDelayedEvent:] + 1984
# 9   AppKit                              0x000000018d049124 -[NSWindow(NSEventRouting) sendEvent:] + 284
# 10  AppKit                              0x000000018d04825c -[NSApplication(NSEvent) sendEvent:] + 1920
# 11  cv2.abi3.so                         0x000000012ecfa37c cvWaitKey + 380
# 12  cv2.abi3.so                         0x000000012ecf44dc _ZN2cv9waitKeyExEi + 168
# 13  cv2.abi3.so                         0x000000012ecf45d4 _ZN2cv7waitKeyEi + 48
# 14  cv2.abi3.so                         0x000000012e34b468 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 15  Python                              0x00000001034d1c34 cfunction_call + 60
# 16  Python                              0x000000010346da94 _PyObject_MakeTpCall + 128
# 17  Python                              0x0000000103590e34 _PyEval_EvalFrameDefault + 53004
# 18  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 19  Python                              0x000000010357d50c builtin_exec + 428
# 20  Python                              0x0000000103592ae0 _PyEval_EvalFrameDefault + 60344
# 21  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 22  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 23  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 24  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 25  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 26  Python                              0x000000010348cbf4 gen_send + 36
# 27  Python                              0x000000010347f54c method_vectorcall_O + 100
# 28  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 29  Python                              0x000000010359689c _PyEval_Vector + 156
# 30  Python                              0x0000000103471dd8 method_vectorcall + 272
# 31  Python                              0x000000010346e840 _PyVectorcall_Call + 116
# 32  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 33  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 34  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 35  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 36  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 37  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 38  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 39  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 40  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 41  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 42  _asyncio.cpython-311-darwin.so      0x0000000102c884e8 task_step_impl + 440
# 43  _asyncio.cpython-311-darwin.so      0x0000000102c882bc task_step + 52
# 44  _asyncio.cpython-311-darwin.so      0x0000000102c88d5c task_wakeup + 148
# 45  Python                              0x00000001034d2904 cfunction_vectorcall_O + 92
# 46  Python                              0x00000001035bc4f4 _PyObject_VectorcallTstate.4587 + 96
# 47  Python                              0x00000001035bc3dc context_run + 216
# 48  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 49  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 50  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 51  Python                              0x000000010357d50c builtin_exec + 428
# 52  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 53  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 54  Python                              0x000000010359689c _PyEval_Vector + 156
# 55  Python                              0x000000010362384c pymain_run_module + 256
# 56  Python                              0x00000001036232ec Py_RunMain + 1784
# 57  Python                              0x000000010362449c pymain_main + 52
# 58  Python                              0x0000000103624cd4 Py_BytesMain + 40
# 59  dyld                                0x0000000189893e50 start + 2544
# 1   HIToolbox                           0x000000019336f90c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x0000000193387214 SetMenuBarObscured + 120
# 3   HIToolbox                           0x000000019338e390 _ZN13HIApplication11FrontUILostEv + 44
# 4   HIToolbox                           0x000000019338704c _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 528
# 5   HIToolbox                           0x0000000193380f70 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 204
# 6   HIToolbox                           0x0000000193347cd0 _NotifyEventLoopObservers + 176
# 7   HIToolbox                           0x000000019338096c AcquireEventFromQueue + 432
# 8   HIToolbox                           0x000000019336fc84 ReceiveNextEventCommon + 320
# 9   HIToolbox                           0x000000019336fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 10  AppKit                              0x000000018cf1c424 _DPSNextEvent + 632
# 11  AppKit                              0x000000018cf1b5b4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 12  cv2.abi3.so                         0x000000012ecfa358 cvWaitKey + 344
# 13  cv2.abi3.so                         0x000000012ecf44dc _ZN2cv9waitKeyExEi + 168
# 14  cv2.abi3.so                         0x000000012ecf45d4 _ZN2cv7waitKeyEi + 48
# 15  cv2.abi3.so                         0x000000012e34b468 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  Python                              0x00000001034d1c34 cfunction_call + 60
# 17  Python                              0x000000010346da94 _PyObject_MakeTpCall + 128
# 18  Python                              0x0000000103590e34 _PyEval_EvalFrameDefault + 53004
# 19  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 20  Python                              0x000000010357d50c builtin_exec + 428
# 21  Python                              0x0000000103592ae0 _PyEval_EvalFrameDefault + 60344
# 22  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 23  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 24  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 25  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 26  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 27  Python                              0x000000010348cbf4 gen_send + 36
# 28  Python                              0x000000010347f54c method_vectorcall_O + 100
# 29  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 30  Python                              0x000000010359689c _PyEval_Vector + 156
# 31  Python                              0x0000000103471dd8 method_vectorcall + 272
# 32  Python                              0x000000010346e840 _PyVectorcall_Call + 116
# 33  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 34  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 35  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 36  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 37  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 38  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 39  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 40  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 41  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 42  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 43  _asyncio.cpython-311-darwin.so      0x0000000102c884e8 task_step_impl + 440
# 44  _asyncio.cpython-311-darwin.so      0x0000000102c882bc task_step + 52
# 45  _asyncio.cpython-311-darwin.so      0x0000000102c88d5c task_wakeup + 148
# 46  Python                              0x00000001034d2904 cfunction_vectorcall_O + 92
# 47  Python                              0x00000001035bc4f4 _PyObject_VectorcallTstate.4587 + 96
# 48  Python                              0x00000001035bc3dc context_run + 216
# 49  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 50  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 51  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 52  Python                              0x000000010357d50c builtin_exec + 428
# 53  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 54  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 55  Python                              0x000000010359689c _PyEval_Vector + 156
# 56  Python                              0x000000010362384c pymain_run_module + 256
# 57  Python                              0x00000001036232ec Py_RunMain + 1784
# 58  Python                              0x000000010362449c pymain_main + 52
# 59  Python                              0x0000000103624cd4 Py_BytesMain + 40
# 60  dyld                                0x0000000189893e50 start + 2544
# 1   HIToolbox                           0x00000001933e45c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x000000019338727c SetMenuBarObscured + 224
# 3   HIToolbox                           0x0000000193386ee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 4   HIToolbox                           0x0000000193380fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 5   HIToolbox                           0x0000000193347cd0 _NotifyEventLoopObservers + 176
# 6   AppKit                              0x000000018d0bf5b0 -[NSWindow(NSEventRouting) _handleMouseDownEvent:isDelayedEvent:] + 2428
# 7   AppKit                              0x000000018d049ab8 -[NSWindow(NSEventRouting) _reallySendEvent:isDelayedEvent:] + 1984
# 8   AppKit                              0x000000018d049124 -[NSWindow(NSEventRouting) sendEvent:] + 284
# 9   AppKit                              0x000000018d04825c -[NSApplication(NSEvent) sendEvent:] + 1920
# 10  cv2.abi3.so                         0x000000012ecfa37c cvWaitKey + 380
# 11  cv2.abi3.so                         0x000000012ecf44dc _ZN2cv9waitKeyExEi + 168
# 12  cv2.abi3.so                         0x000000012ecf45d4 _ZN2cv7waitKeyEi + 48
# 13  cv2.abi3.so                         0x000000012e34b468 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 14  Python                              0x00000001034d1c34 cfunction_call + 60
# 15  Python                              0x000000010346da94 _PyObject_MakeTpCall + 128
# 16  Python                              0x0000000103590e34 _PyEval_EvalFrameDefault + 53004
# 17  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 18  Python                              0x000000010357d50c builtin_exec + 428
# 19  Python                              0x0000000103592ae0 _PyEval_EvalFrameDefault + 60344
# 20  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 21  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 22  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 23  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 24  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 25  Python                              0x000000010348cbf4 gen_send + 36
# 26  Python                              0x000000010347f54c method_vectorcall_O + 100
# 27  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 28  Python                              0x000000010359689c _PyEval_Vector + 156
# 29  Python                              0x0000000103471dd8 method_vectorcall + 272
# 30  Python                              0x000000010346e840 _PyVectorcall_Call + 116
# 31  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 32  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 33  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 34  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 35  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 36  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 37  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 38  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 39  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 40  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 41  _asyncio.cpython-311-darwin.so      0x0000000102c884e8 task_step_impl + 440
# 42  _asyncio.cpython-311-darwin.so      0x0000000102c882bc task_step + 52
# 43  _asyncio.cpython-311-darwin.so      0x0000000102c88d5c task_wakeup + 148
# 44  Python                              0x00000001034d2904 cfunction_vectorcall_O + 92
# 45  Python                              0x00000001035bc4f4 _PyObject_VectorcallTstate.4587 + 96
# 46  Python                              0x00000001035bc3dc context_run + 216
# 47  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 48  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 49  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 50  Python                              0x000000010357d50c builtin_exec + 428
# 51  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 52  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 53  Python                              0x000000010359689c _PyEval_Vector + 156
# 54  Python                              0x000000010362384c pymain_run_module + 256
# 55  Python                              0x00000001036232ec Py_RunMain + 1784
# 56  Python                              0x000000010362449c pymain_main + 52
# 57  Python                              0x0000000103624cd4 Py_BytesMain + 40
# 58  dyld                                0x0000000189893e50 start + 2544
# 1   HIToolbox                           0x000000019336f90c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x0000000193387214 SetMenuBarObscured + 120
# 3   HIToolbox                           0x000000019338e390 _ZN13HIApplication11FrontUILostEv + 44
# 4   HIToolbox                           0x000000019338704c _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 528
# 5   HIToolbox                           0x0000000193380f70 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 204
# 6   HIToolbox                           0x0000000193347cd0 _NotifyEventLoopObservers + 176
# 7   HIToolbox                           0x000000019338096c AcquireEventFromQueue + 432
# 8   HIToolbox                           0x000000019336fc84 ReceiveNextEventCommon + 320
# 9   HIToolbox                           0x000000019336fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 10  AppKit                              0x000000018cf1c424 _DPSNextEvent + 632
# 11  AppKit                              0x000000018cf1b5b4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 12  cv2.abi3.so                         0x000000012ecfa358 cvWaitKey + 344
# 13  cv2.abi3.so                         0x000000012ecf44dc _ZN2cv9waitKeyExEi + 168
# 14  cv2.abi3.so                         0x000000012ecf45d4 _ZN2cv7waitKeyEi + 48
# 15  cv2.abi3.so                         0x000000012e34b468 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  Python                              0x00000001034d1c34 cfunction_call + 60
# 17  Python                              0x000000010346da94 _PyObject_MakeTpCall + 128
# 18  Python                              0x0000000103590e34 _PyEval_EvalFrameDefault + 53004
# 19  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 20  Python                              0x000000010357d50c builtin_exec + 428
# 21  Python                              0x0000000103592ae0 _PyEval_EvalFrameDefault + 60344
# 22  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 23  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 24  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 25  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 26  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 27  Python                              0x000000010348cbf4 gen_send + 36
# 28  Python                              0x000000010347f54c method_vectorcall_O + 100
# 29  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 30  Python                              0x000000010359689c _PyEval_Vector + 156
# 31  Python                              0x0000000103471dd8 method_vectorcall + 272
# 32  Python                              0x000000010346e840 _PyVectorcall_Call + 116
# 33  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 34  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 35  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 36  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 37  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 38  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 39  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 40  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 41  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 42  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 43  _asyncio.cpython-311-darwin.so      0x0000000102c884e8 task_step_impl + 440
# 44  _asyncio.cpython-311-darwin.so      0x0000000102c882bc task_step + 52
# 45  _asyncio.cpython-311-darwin.so      0x0000000102c88d5c task_wakeup + 148
# 46  Python                              0x00000001034d2904 cfunction_vectorcall_O + 92
# 47  Python                              0x00000001035bc4f4 _PyObject_VectorcallTstate.4587 + 96
# 48  Python                              0x00000001035bc3dc context_run + 216
# 49  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 50  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 51  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 52  Python                              0x000000010357d50c builtin_exec + 428
# 53  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 54  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 55  Python                              0x000000010359689c _PyEval_Vector + 156
# 56  Python                              0x000000010362384c pymain_run_module + 256
# 57  Python                              0x00000001036232ec Py_RunMain + 1784
# 58  Python                              0x000000010362449c pymain_main + 52
# 59  Python                              0x0000000103624cd4 Py_BytesMain + 40
# 60  dyld                                0x0000000189893e50 start + 2544
# 1   HIToolbox                           0x00000001933e45c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x000000019338727c SetMenuBarObscured + 224
# 3   HIToolbox                           0x0000000193386ee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 4   HIToolbox                           0x0000000193380fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 5   HIToolbox                           0x0000000193347cd0 _NotifyEventLoopObservers + 176
# 6   AppKit                              0x000000018d0bf5b0 -[NSWindow(NSEventRouting) _handleMouseDownEvent:isDelayedEvent:] + 2428
# 7   AppKit                              0x000000018d049ab8 -[NSWindow(NSEventRouting) _reallySendEvent:isDelayedEvent:] + 1984
# 8   AppKit                              0x000000018d049124 -[NSWindow(NSEventRouting) sendEvent:] + 284
# 9   AppKit                              0x000000018d04825c -[NSApplication(NSEvent) sendEvent:] + 1920
# 10  cv2.abi3.so                         0x000000012ecfa37c cvWaitKey + 380
# 11  cv2.abi3.so                         0x000000012ecf44dc _ZN2cv9waitKeyExEi + 168
# 12  cv2.abi3.so                         0x000000012ecf45d4 _ZN2cv7waitKeyEi + 48
# 13  cv2.abi3.so                         0x000000012e34b468 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 14  Python                              0x00000001034d1c34 cfunction_call + 60
# 15  Python                              0x000000010346da94 _PyObject_MakeTpCall + 128
# 16  Python                              0x0000000103590e34 _PyEval_EvalFrameDefault + 53004
# 17  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 18  Python                              0x000000010357d50c builtin_exec + 428
# 19  Python                              0x0000000103592ae0 _PyEval_EvalFrameDefault + 60344
# 20  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 21  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 22  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 23  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 24  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 25  Python                              0x000000010348cbf4 gen_send + 36
# 26  Python                              0x000000010347f54c method_vectorcall_O + 100
# 27  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 28  Python                              0x000000010359689c _PyEval_Vector + 156
# 29  Python                              0x0000000103471dd8 method_vectorcall + 272
# 30  Python                              0x000000010346e840 _PyVectorcall_Call + 116
# 31  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 32  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 33  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 34  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 35  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 36  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 37  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 38  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 39  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 40  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 41  _asyncio.cpython-311-darwin.so      0x0000000102c884e8 task_step_impl + 440
# 42  _asyncio.cpython-311-darwin.so      0x0000000102c882bc task_step + 52
# 43  _asyncio.cpython-311-darwin.so      0x0000000102c88d5c task_wakeup + 148
# 44  Python                              0x00000001034d2904 cfunction_vectorcall_O + 92
# 45  Python                              0x00000001035bc4f4 _PyObject_VectorcallTstate.4587 + 96
# 46  Python                              0x00000001035bc3dc context_run + 216
# 47  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 48  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 49  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 50  Python                              0x000000010357d50c builtin_exec + 428
# 51  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 52  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 53  Python                              0x000000010359689c _PyEval_Vector + 156
# 54  Python                              0x000000010362384c pymain_run_module + 256
# 55  Python                              0x00000001036232ec Py_RunMain + 1784
# 56  Python                              0x000000010362449c pymain_main + 52
# 57  Python                              0x0000000103624cd4 Py_BytesMain + 40
# 58  dyld                                0x0000000189893e50 start + 2544
# 1   HIToolbox                           0x000000019336f90c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x0000000193387214 SetMenuBarObscured + 120
# 3   HIToolbox                           0x000000019338e390 _ZN13HIApplication11FrontUILostEv + 44
# 4   HIToolbox                           0x000000019338704c _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 528
# 5   HIToolbox                           0x0000000193380f70 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 204
# 6   HIToolbox                           0x0000000193347cd0 _NotifyEventLoopObservers + 176
# 7   HIToolbox                           0x000000019338096c AcquireEventFromQueue + 432
# 8   HIToolbox                           0x000000019336fc84 ReceiveNextEventCommon + 320
# 9   HIToolbox                           0x000000019336fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 10  AppKit                              0x000000018cf1c424 _DPSNextEvent + 632
# 11  AppKit                              0x000000018cf1b5b4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 12  cv2.abi3.so                         0x000000012ecfa358 cvWaitKey + 344
# 13  cv2.abi3.so                         0x000000012ecf44dc _ZN2cv9waitKeyExEi + 168
# 14  cv2.abi3.so                         0x000000012ecf45d4 _ZN2cv7waitKeyEi + 48
# 15  cv2.abi3.so                         0x000000012e34b468 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  Python                              0x00000001034d1c34 cfunction_call + 60
# 17  Python                              0x000000010346da94 _PyObject_MakeTpCall + 128
# 18  Python                              0x0000000103590e34 _PyEval_EvalFrameDefault + 53004
# 19  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 20  Python                              0x000000010357d50c builtin_exec + 428
# 21  Python                              0x0000000103592ae0 _PyEval_EvalFrameDefault + 60344
# 22  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 23  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 24  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 25  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 26  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 27  Python                              0x000000010348cbf4 gen_send + 36
# 28  Python                              0x000000010347f54c method_vectorcall_O + 100
# 29  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 30  Python                              0x000000010359689c _PyEval_Vector + 156
# 31  Python                              0x0000000103471dd8 method_vectorcall + 272
# 32  Python                              0x000000010346e840 _PyVectorcall_Call + 116
# 33  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 34  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 35  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 36  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 37  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 38  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 39  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 40  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 41  Python                              0x0000000103587a7c _PyEval_EvalFrameDefault + 15188
# 42  Python                              0x000000010348c3e4 gen_send_ex2 + 204
# 43  _asyncio.cpython-311-darwin.so      0x0000000102c884e8 task_step_impl + 440
# 44  _asyncio.cpython-311-darwin.so      0x0000000102c882bc task_step + 52
# 45  _asyncio.cpython-311-darwin.so      0x0000000102c88d5c task_wakeup + 148
# 46  Python                              0x00000001034d2904 cfunction_vectorcall_O + 92
# 47  Python                              0x00000001035bc4f4 _PyObject_VectorcallTstate.4587 + 96
# 48  Python                              0x00000001035bc3dc context_run + 216
# 49  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 50  Python                              0x0000000103593980 _PyEval_EvalFrameDefault + 64088
# 51  Python                              0x0000000103582cac PyEval_EvalCode + 276
# 52  Python                              0x000000010357d50c builtin_exec + 428
# 53  Python                              0x00000001034d2644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 54  Python                              0x0000000103590d4c _PyEval_EvalFrameDefault + 52772
# 55  Python                              0x000000010359689c _PyEval_Vector + 156
# 56  Python                              0x000000010362384c pymain_run_module + 256
# 57  Python                              0x00000001036232ec Py_RunMain + 1784
# 58  Python                              0x000000010362449c pymain_main + 52
# 59  Python                              0x0000000103624cd4 Py_BytesMain + 40
# 60  dyld                                0x0000000189893e50 start + 2544
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 26
#      23 cap = cv2.VideoCapture(0)
#      25 while True:
# ---> 26     ret, frame = cap.read()
#      27     cv2.imshow('Our Live Sketcher', sketch(frame))
#      28     if cv2.waitKey(1) == 13: #13 is the Enter Key
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
